# %% [markdown]
# # 实习四 基于SQL实现机器学习的基本概念
# 成员：陈嘉2000013094  马佳媛2000013121  黄粤2000013095

# %%
# %load_ext sql
import pymysql 
pymysql.install_as_MySQLdb()
# %sql mysql://stu2000013121:stu2000013121@162.105.146.37:43306
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql show databases
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 4 rows affected.
# [('dataset',),
#  ('information_schema',),
#  ('performance_schema',),
#  ('stu2000013121',)]

# %%
# %sql use dataset
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 0 rows affected.
# []

# %%
# %sql show tables;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 18 rows affected.
# [('TheWorldHappinessReport2015',),
#  ('TheWorldHappinessReport2016',),
#  ('TheWorldHappinessReport2017',),
#  ('TheWorldHappinessReport2018',),
#  ('TheWorldHappinessReport2019',),
#  ('application',),
#  ('breast_cancer',),
#  ('diamonds',),
#  ('itemscore',),
#  ('movieGenres',),
#  ('movies',),
#  ('ratings',),
#  ('skyline_negative_correlation',),
#  ('skyline_positive_correlation',),
#  ('skyline_random',),
#  ('supermarketTrans',),
#  ('tags',),
#  ('xzqh',)]

# %% [markdown]
# ## 练习一：发现数据中隐含的辛普森悖论

# %% [markdown]
# **辛普森悖论：**   在分组比较中都占优势的一方，在总评中有时反而是失势的一方

# %%
# %sql SELECT * FROM application;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 240 rows affected.
# [('1', 'female', 'business', 'yes'),
#  ('10', 'female', 'business', 'yes'),
#  ('100', 'female', 'business', 'no'),
#  ('101', 'male', 'business', 'yes'),
#  ('102', 'male', 'business', 'yes'),
#  ('103', 'male', 'business', 'yes'),
#  ('104', 'male', 'business', 'yes'),
#  ('105', 'male', 'business', 'yes'),
#  ('106', 'male', 'business', 'yes'),
#  ('107', 'male', 'business', 'yes'),
#  ('108', 'male', 'business', 'yes'),
#  ('109', 'male', 'business', 'yes'),
#  ('11', 'female', 'business', 'yes'),
#  ('110', 'male', 'business', 'yes'),
#  ('111', 'male', 'business', 'yes'),
#  ('112', 'male', 'business', 'yes'),
#  ('113', 'male', 'business', 'yes'),
#  ('114', 'male', 'business', 'yes'),
#  ('115', 'male', 'business', 'yes'),
#  ('116', 'male', 'business', 'no'),
#  ('117', 'male', 'business', 'no'),
#  ('118', 'male', 'business', 'no'),
#  ('119', 'male', 'business', 'no'),
# ...

# %% [markdown]
# ### 任务一：生成报表

# %%
# %%sql
# select (case
# WHEN department ='business' then '商学院'
# WHEN department ='law' then '法学院'
# WHEN GROUPING(department) = 1 THEN '总计'
# end )as 学院,
# sum(IF(gender = 'female',1,0))as 女生申请,
# sum(IF(gender = 'female'&&acceptance = 'yes',1,0))as 女生录取,
# concat(round(sum(IF(gender = 'female'&&acceptance = 'yes',1,0))/sum(IF(gender = 'female',1,0))*100),'%') as 女生录取率,
# sum(IF(gender = 'male',1,0))as 男生申请,
# sum(IF(gender = 'male'&&acceptance = 'yes',1,0))as 男生录取,
# concat(round(sum(IF(gender = 'male'&&acceptance = 'yes',1,0))/sum(IF(gender = 'male',1,0))*100),'%') as 男生录取率,
# count(id) as 合计申请,
# sum(IF(acceptance = 'yes',1,0))as 合计录取,
# concat(round(sum(IF(acceptance = 'yes',1,0))/count(id)*100,1),'%') as 合计录取率
# from application
# group by department with rollup
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 3 rows affected.
# [('商学院', Decimal('100'), Decimal('49'), '49%', Decimal('20'), Decimal('15'), '75%', 120, Decimal('64'), '53.3%'),
#  ('法学院', Decimal('20'), Decimal('1'), '5%', Decimal('100'), Decimal('10'), '10%', 120, Decimal('11'), '9.2%'),
#  ('总计', Decimal('120'), Decimal('50'), '42%', Decimal('120'), Decimal('25'), '21%', 240, Decimal('75'), '31.3%')]

# %% [markdown]
# 由上表可知，商学院与法学院的男生录取率均高于女生录取率，但在总计中女生录取率高于男生录取率。在分组比较中男生都占优势，但在总评中反而是失势的一方，因此本录取信息中存在辛普森悖论。
#
# ***

# %% [markdown]
# ### 任务二：使用SQL寻找一般性的辛普森悖论存在的方法
# 概率计算如下：

# %%
# %%sql
# select
# concat(round(sum(IF(gender = 'male'&&acceptance = 'yes',1,0))/sum(IF(gender = 'male',1,0)),2)) as 'P(yes│男生)',
# concat(round(sum(IF(gender = 'female'&&acceptance = 'yes',1,0))/sum(IF(gender = 'female',1,0)),2)) as 'P(yes|女生)',
# concat(round(sum(IF(gender = 'male'&&acceptance = 'no',1,0))/sum(IF(gender = 'male',1,0)),2)) as 'P(no│男生)',
# concat(round(sum(IF(gender = 'female'&&acceptance = 'no',1,0))/sum(IF(gender = 'female',1,0)),2)) as 'P(no|女生)',
# concat(round(sum(IF(gender = 'male'&&acceptance = 'yes'&&department = 'business',1,0))/sum(IF(gender = 'male'&&department = 'business',1,0)),2)) as 'P(yes│<男生,商学院>)',
# concat(round(sum(IF(gender = 'female'&&acceptance = 'yes'&&department = 'business',1,0))/sum(IF(gender = 'female'&&department = 'business',1,0)),2)) as 'P(yes│<女生,商学院>)',
# concat(round(sum(IF(gender = 'male'&&acceptance = 'yes'&&department = 'law',1,0))/sum(IF(gender = 'male'&&department = 'law',1,0)),2)) as 'P(yes│<男生,法学院>)',
# concat(round(sum(IF(gender = 'female'&&acceptance = 'yes'&&department = 'law',1,0))/sum(IF(gender = 'female'&&department = 'law',1,0)),2)) as 'P(yes│<女生,法学院>)',
# concat(round(sum(IF(gender = 'male'&&acceptance = 'no'&&department = 'business',1,0))/sum(IF(gender = 'male'&&department = 'business',1,0)),2)) as 'P(no│<男生,商学院>)',
# concat(round(sum(IF(gender = 'female'&&acceptance = 'no'&&department = 'business',1,0))/sum(IF(gender = 'female'&&department = 'business',1,0)),2)) as 'P(no│<女生,商学院>)',
# concat(round(sum(IF(gender = 'male'&&acceptance = 'no'&&department = 'law',1,0))/sum(IF(gender = 'male'&&department = 'law',1,0)),2)) as 'P(no│<男生,法学院>)',
# concat(round(sum(IF(gender = 'female'&&acceptance = 'no'&&department = 'law',1,0))/sum(IF(gender = 'female'&&department = 'law',1,0)),2)) as 'P(no│<女生,法学院>)'
#
# from application
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 1 rows affected.
# [('0.21', '0.42', '0.79', '0.58', '0.75', '0.49', '0.10', '0.05', '0.25', '0.51', '0.90', '0.95')]

# %% [markdown]
# 寻找符合辛普森悖论的条件概率：

# %% [markdown]
# 由上表可知:
#
#     P(yes|<男生，商学院>) > P(yes|<女生，商学院>) ∧
#     P(yes|<男生，法学院>) > P(yes|<女生，法学院>) ∧
#     P(yes|男生) < P(yes|女生)
#     ⟹
#     P(no|<女生，商学院>)/P(yes|<女生，商学院>) > P(no|<男生，商学院>)/P(yes|<男生，商学院>) ∧
#     P(no|<女生，法学院>)/P(yes|<女生，法学院>) > P(no|<男生，法学院>)/P(yes|<男生，法学院>) ∧
#     P(no|女生)/P(yes|女生) < P(no|男生)/P(yes|男生)
#
# 因此，这些条件概率符合辛普森悖论
#
# ***

# %% [markdown]
# ## 练习二 KNN分类

# %% [markdown]
# 本次实习选择**威斯康辛乳腺癌数据集**进行机器学习的训练

# %% [markdown]
# ### 任务一 属性值的预处理

# %%
# %sql select * from breast_cancer;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 699 rows affected.
# [(1, 1000025, '5', '1', '1', '1', '2', '1', '3', '1', '1', '2'),
#  (2, 1002945, '5', '4', '4', '5', '7', '10', '3', '2', '1', '2'),
#  (3, 1015425, '3', '1', '1', '1', '2', '2', '3', '1', '1', '2'),
#  (4, 1016277, '6', '8', '8', '1', '3', '4', '3', '7', '1', '2'),
#  (5, 1017023, '4', '1', '1', '3', '2', '1', '3', '1', '1', '2'),
#  (6, 1017122, '8', '10', '10', '8', '7', '10', '9', '7', '1', '4'),
#  (7, 1018099, '1', '1', '1', '1', '2', '10', '3', '1', '1', '2'),
#  (8, 1018561, '2', '1', '2', '1', '2', '1', '3', '1', '1', '2'),
#  (9, 1033078, '2', '1', '1', '1', '2', '1', '1', '1', '5', '2'),
#  (10, 1033078, '4', '2', '1', '1', '2', '1', '2', '1', '1', '2'),
#  (11, 1035283, '1', '1', '1', '1', '1', '1', '3', '1', '1', '2'),
#  (12, 1036172, '2', '1', '1', '1', '2', '1', '2', '1', '1', '2'),
#  (13, 1041801, '5', '3', '3', '3', '2', '3', '4', '4', '1', '4'),
# ...

# %% [markdown]
# 考虑到bare_nuclei一项中有取值为'?'的特殊行，可能会对后续距离的计算产生影响，因此在进行转换时将这些含有特殊符号的行省略
#
# ***
#
# ### 属性重命名
#
# 为方便后续的读写，在筛选可用行数据的同时，对属性值进行重命名操作

# %%
# %%sql
# drop table if exists stu2000013121.new_cancer;
# create table stu2000013121.new_cancer as
#     (select sample_number as 编号, thickness as 厚度,
#     cell_size as 大小, cell_shape as 形状, marginal_adhesion as 边缘,
#     single_epithelial_cell_size as 单核大小, bare_nuclei as 裸核,
#     bland_chromatin as 染色质, normal_nucleoli as 核心, mitoses as 有丝分裂, class as 分类
#     from breast_cancer
#     where bare_nuclei!='?')
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 0 rows affected.
# 683 rows affected.
# []

# %%
# %%sql
# use stu2000013121;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 7 rows affected.
# [('acc_K',),
#  ('distance',),
#  ('knn_cnt',),
#  ('knn_pre',),
#  ('new_cancer',),
#  ('test_data',),
#  ('train_data',)]

# %%
# %%sql
# select * from new_cancer
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 683 rows affected.
# [(1000025, '5', '1', '1', '1', '2', '1', '3', '1', '1', '2'),
#  (1002945, '5', '4', '4', '5', '7', '10', '3', '2', '1', '2'),
#  (1015425, '3', '1', '1', '1', '2', '2', '3', '1', '1', '2'),
#  (1016277, '6', '8', '8', '1', '3', '4', '3', '7', '1', '2'),
#  (1017023, '4', '1', '1', '3', '2', '1', '3', '1', '1', '2'),
#  (1017122, '8', '10', '10', '8', '7', '10', '9', '7', '1', '4'),
#  (1018099, '1', '1', '1', '1', '2', '10', '3', '1', '1', '2'),
#  (1018561, '2', '1', '2', '1', '2', '1', '3', '1', '1', '2'),
#  (1033078, '2', '1', '1', '1', '2', '1', '1', '1', '5', '2'),
#  (1033078, '4', '2', '1', '1', '2', '1', '2', '1', '1', '2'),
#  (1035283, '1', '1', '1', '1', '1', '1', '3', '1', '1', '2'),
#  (1036172, '2', '1', '1', '1', '2', '1', '2', '1', '1', '2'),
#  (1041801, '5', '3', '3', '3', '2', '3', '4', '4', '1', '4'),
#  (1043999, '1', '1', '1', '1', '2', '3', '3', '1', '1', '2'),
# ...

# %% [markdown]
# 经过统计后发现，class这一属性项刚好为二值分类，因此将class作为数据标签进行分类，其余属性均作为训练变量

# %%
# %%sql
# select 分类 from new_cancer
# group by 分类
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 2 rows affected.
# [('2',), ('4',)]

# %% [markdown]
# 由于属性均为数值型属性，并不需要进行热值编码操作，
# 因此只对厚度、大小、形状、边缘、单核大小、裸核、染色质、核心、有丝分裂属性进行归一化操作
#
# ***
#
# ### Min-Max归一化（Min-Max Normalization）
# 也称为离差标准化，是对原始数据的线性变换，使结果值映射到[0 – 1]之间。转换函数如下：
#
# $$ x^{*} = \frac{x − min}{max − min} $$
#
# 其中max为样本数据的最大值，min为样本数据的最小值。在每次实验中，每个属性的最大值均为10，最小值均为1
#
# 本实习中MinMaxScaler将通过估计器分别缩放和转换每个元素成[0,1]范围的值。

# %%
# %%sql
# update new_cancer set
#         厚度 = (厚度-1)/(10-1),
#         大小 = (大小-1)/(10-1),
#         形状 = (形状-1)/(10-1),
#         边缘 = (边缘-1)/(10-1),
#         单核大小 = (单核大小-1)/(10-1),
#         裸核 = (裸核-1)/(10-1),
#         染色质 = (染色质-1)/(10-1),
#         核心 = (核心-1)/(10-1),
#         有丝分裂 = (有丝分裂-1)/(10-1)
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 683 rows affected.
# []

# %%
# %%sql
# select * from new_cancer
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 683 rows affected.
# [(1000025, '0.44444444', '0', '0', '0', '0.11111111', '0', '0.22222222', '0', '0', '2'),
#  (1002945, '0.44444444', '0.33333333', '0.33333333', '0.44444444', '0.66666667', '1', '0.22222222', '0.11111111', '0', '2'),
#  (1015425, '0.22222222', '0', '0', '0', '0.11111111', '0.11111111', '0.22222222', '0', '0', '2'),
#  (1016277, '0.55555556', '0.77777778', '0.77777778', '0', '0.22222222', '0.33333333', '0.22222222', '0.66666667', '0', '2'),
#  (1017023, '0.33333333', '0', '0', '0.22222222', '0.11111111', '0', '0.22222222', '0', '0', '2'),
#  (1017122, '0.77777778', '1', '1', '0.77777778', '0.66666667', '1', '0.88888889', '0.66666667', '0', '4'),
#  (1018099, '0', '0', '0', '0', '0.11111111', '1', '0.22222222', '0', '0', '2'),
#  (1018561, '0.11111111', '0', '0.11111111', '0', '0.11111111', '0', '0.22222222', '0', '0', '2'),
#  (1033078, '0.11111111', '0', '0', '0', '0.11111111', '0', '0', '0', '0.44444444', '2'),
# ...

# %% [markdown]
# ### 任务二 数据集划分

# %% [markdown]
# #### 随机数划分

# %% [markdown]
# 插入区间为[0,1]的随机数，若随机数大于0.7则作为测试组，否则作为训练组

# %%
# %%sql
# alter table new_cancer add 随机数 float not NULL;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 0 rows affected.
# []

# %%
# %%sql
# update new_cancer set 随机数 = rand();
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 683 rows affected.
# []

# %%
# %%sql
# select * from new_cancer
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 683 rows affected.
# [(1000025, '0.44444444', '0', '0', '0', '0.11111111', '0', '0.22222222', '0', '0', '2', 0.105875),
#  (1002945, '0.44444444', '0.33333333', '0.33333333', '0.44444444', '0.66666667', '1', '0.22222222', '0.11111111', '0', '2', 0.546816),
#  (1015425, '0.22222222', '0', '0', '0', '0.11111111', '0.11111111', '0.22222222', '0', '0', '2', 0.416452),
#  (1016277, '0.55555556', '0.77777778', '0.77777778', '0', '0.22222222', '0.33333333', '0.22222222', '0.66666667', '0', '2', 0.441815),
#  (1017023, '0.33333333', '0', '0', '0.22222222', '0.11111111', '0', '0.22222222', '0', '0', '2', 0.959718),
#  (1017122, '0.77777778', '1', '1', '0.77777778', '0.66666667', '1', '0.88888889', '0.66666667', '0', '4', 0.473146),
#  (1018099, '0', '0', '0', '0', '0.11111111', '1', '0.22222222', '0', '0', '2', 0.486577),
#  (1018561, '0.11111111', '0', '0.11111111', '0', '0.11111111', '0', '0.22222222', '0', '0', '2', 0.013447),
# ...

# %%
# %%sql
# drop table if exists test_data;
# create table test_data as
#     (select * from new_cancer
#      where 随机数 >= 0.7)
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 0 rows affected.
# 196 rows affected.
# []

# %%
# %%sql
# drop table if exists train_data;
# create table train_data as
#     (select * from new_cancer
#      where 随机数 < 0.7)
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 0 rows affected.
# 487 rows affected.
# []

# %%
# %%sql
# select * from test_data
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 196 rows affected.
# [(1017023, '0.33333333', '0', '0', '0.22222222', '0.11111111', '0', '0.22222222', '0', '0', '2', 0.959718),
#  (1033078, '0.33333333', '0.11111111', '0', '0', '0.11111111', '0', '0.11111111', '0', '0', '2', 0.997175),
#  (1036172, '0.11111111', '0', '0', '0', '0.11111111', '0', '0.11111111', '0', '0', '2', 0.825306),
#  (1043999, '0', '0', '0', '0', '0.11111111', '0.22222222', '0.22222222', '0', '0', '2', 0.706245),
#  (1047630, '0.66666667', '0.33333333', '0.55555556', '0.33333333', '0.55555556', '0', '0.33333333', '0.22222222', '0', '4', 0.990894),
#  (1054590, '0.66666667', '0.22222222', '0.11111111', '1', '0.44444444', '1', '0.44444444', '0.33333333', '0.33333333', '4', 0.87111),
#  (1056784, '0.22222222', '0', '0', '0', '0.11111111', '0', '0.11111111', '0', '0', '2', 0.76034),
#  (1059552, '0', '0', '0', '0', '0.11111111', '0', '0.22222222', '0', '0', '2', 0.977499),
# ...

# %%
# %%sql
# select * from train_data
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 487 rows affected.
# [(1000025, '0.44444444', '0', '0', '0', '0.11111111', '0', '0.22222222', '0', '0', '2', 0.105875),
#  (1002945, '0.44444444', '0.33333333', '0.33333333', '0.44444444', '0.66666667', '1', '0.22222222', '0.11111111', '0', '2', 0.546816),
#  (1015425, '0.22222222', '0', '0', '0', '0.11111111', '0.11111111', '0.22222222', '0', '0', '2', 0.416452),
#  (1016277, '0.55555556', '0.77777778', '0.77777778', '0', '0.22222222', '0.33333333', '0.22222222', '0.66666667', '0', '2', 0.441815),
#  (1017122, '0.77777778', '1', '1', '0.77777778', '0.66666667', '1', '0.88888889', '0.66666667', '0', '4', 0.473146),
#  (1018099, '0', '0', '0', '0', '0.11111111', '1', '0.22222222', '0', '0', '2', 0.486577),
#  (1018561, '0.11111111', '0', '0.11111111', '0', '0.11111111', '0', '0.22222222', '0', '0', '2', 0.013447),
#  (1033078, '0.11111111', '0', '0', '0', '0.11111111', '0', '0', '0', '0.44444444', '2', 0.607503),
# ...

# %% [markdown]
# ### 任务三 实现KNN算法

# %% [markdown]
# 把测试集和训练集样本之间的距离计算出来保存到**distance表**中，先确定一个K，针对每个测试集中的样本，选取前K个最近的训练集样本，根据这K个样本的最多类标签数决定测试样本的类别。并给出正确率。本实习使用欧式距离。
#
# **欧式距离**阐述如下：
#
# 若样本数据有n个特征，且两点A和B的坐标表示为：
#
# $$A(x_{11},x_{12},x_{13},...,x_{1n})$$
# $$B(x_{21},x_{22},x_{23},...,x_{2n})$$
#
# 则A和B两点之间的欧式距离公式如下：
#
# $$d_{AB} = \sqrt{\sum_{k=1}^{n}{(x_{1k}-x_{2k})}^2}$$

# %%
# %%sql
# drop table if exists distance;
# create table distance as(
#     select test_data.编号 as 测试编号, test_data.分类 as 测试分类, train_data.编号 as 训练编号, train_data.分类 as 训练分类,
#     sqrt(power(test_data.厚度-train_data.厚度,2)+power(test_data.大小-train_data.大小,2)
#          +power(test_data.形状-train_data.形状,2)+power(test_data.边缘-train_data.边缘,2)
#          +power(test_data.单核大小-train_data.单核大小,2)+power(test_data.裸核-train_data.裸核,2)
#          +power(test_data.染色质-train_data.染色质,2)+power(test_data.核心-train_data.核心,2)
#          +power(test_data.有丝分裂-train_data.有丝分裂,2)) as 距离
#     from train_data join test_data
#     order by 测试编号,距离
# );
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 0 rows affected.
# 95452 rows affected.
# []

# %%
# %%sql
# select * from distance
# limit 10;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 10 rows affected.
# [(167528, '2', 1236043, '2', 0.29397236495634194),
#  (167528, '2', 1313982, '2', 0.33333333000000004),
#  (167528, '2', 1181356, '2', 0.36851387095524607),
#  (167528, '2', 743348, '2', 0.40061681269922256),
#  (167528, '2', 1197080, '2', 0.44444444999999994),
#  (167528, '2', 1331405, '2', 0.44444444999999994),
#  (167528, '2', 1257648, '2', 0.4581228499856914),
#  (167528, '2', 431495, '2', 0.45812285241104767),
#  (167528, '2', 1371920, '2', 0.45812285241104767),
#  (167528, '2', 1197979, '2', 0.45812285241104767)]

# %% [markdown]
# 对于每一个测试编号，取前K个距离的分类值进行统计计数

# %%
# %%sql
# drop table if exists knn_cnt;
# create table knn_cnt as(
#     select 测试编号, 训练分类, count(*) as 分类数目
#     from (select 测试编号, 训练分类 from
#     (select 测试编号, 距离, 训练分类,
#          @row_number := if(@test = 测试编号, @row_number + 1, 1) as row_num,
#          @test:=测试编号 as test
#         from distance)
#     as tmp where row_num <= 17) as a
#     group by 测试编号,训练分类
# );
#
# select * from knn_cnt;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 0 rows affected.
# 231 rows affected.
# 231 rows affected.
# [(167528, '2', 17),
#  (183913, '2', 17),
#  (191250, '4', 17),
#  (274137, '4', 17),
#  (303213, '4', 17),
#  (390840, '4', 17),
#  (428903, '2', 14),
#  (428903, '4', 3),
#  (434518, '2', 17),
#  (452264, '2', 17),
#  (474162, '4', 17),
#  (492268, '4', 17),
#  (493452, '2', 17),
#  (508234, '4', 17),
#  (521441, '2', 17),
#  (527337, '2', 17),
#  (527363, '4', 17),
#  (529329, '4', 17),
#  (560680, '2', 17),
#  (566346, '2', 17),
#  (601265, '4', 17),
#  (606722, '4', 16),
#  (606722, '2', 1),
#  (625201, '2', 17),
#  (635844, '4', 17),
#  (640712, '2', 17),
#  (654546, '2', 17),
#  (666942, '2', 17),
#  (667204, '4', 17),
#  (677910, '4', 1),
#  (677910, '2', 16),
#  (693702, '2', 17),
#  (704097, '2', 17),
#  (709287, '4', 17),
#  (718641, '2', 17),
#  (733639, '2', 17),
#  (733823, '4', 16),
#  (733823, '2', 1),
#  (734111, '2', 17),
#  (749653, '2', 17),
# ...

# %% [markdown]
# 通过取最值从统计分类中选出较多的分类作为预测分类结果，存入**knn_pre**中

# %%
# %%sql
# drop table if exists knn_pre;
# create table knn_pre as(
#     select knn_cnt.测试编号, knn_cnt.训练分类 as 预测分类 from
#         knn_cnt join
#         (select 测试编号, max(分类数目) as 分类数
#          from knn_cnt group by 测试编号) as knn_max
#         on knn_cnt.测试编号 = knn_max.测试编号
#         where knn_cnt.分类数目 = knn_max.分类数
# );
#
# delete from knn_pre where 测试编号 in (
#     select * from (
#         select 测试编号 from knn_pre
#         group by 测试编号
#         having count(测试编号) > 1
#     ) tmp )
#     and 预测分类 != 2;  #若分类为2和4的数目相同则取2作为分类
#
# select * from knn_pre;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 0 rows affected.
# 194 rows affected.
# 0 rows affected.
# 194 rows affected.
# [(167528, '2'),
#  (183913, '2'),
#  (191250, '4'),
#  (274137, '4'),
#  (303213, '4'),
#  (390840, '4'),
#  (428903, '2'),
#  (434518, '2'),
#  (452264, '2'),
#  (474162, '4'),
#  (492268, '4'),
#  (493452, '2'),
#  (508234, '4'),
#  (521441, '2'),
#  (527337, '2'),
#  (527363, '4'),
#  (529329, '4'),
#  (560680, '2'),
#  (566346, '2'),
#  (601265, '4'),
#  (606722, '4'),
#  (625201, '2'),
#  (635844, '4'),
#  (640712, '2'),
#  (654546, '2'),
#  (666942, '2'),
#  (667204, '4'),
#  (677910, '2'),
#  (693702, '2'),
#  (704097, '2'),
#  (709287, '4'),
#  (718641, '2'),
#  (733639, '2'),
#  (733823, '4'),
#  (734111, '2'),
#  (749653, '2'),
#  (752904, '4'),
#  (764974, '2'),
#  (769612, '2'),
#  (776715, '2'),
#  (792744, '2'),
#  (805448, '2'),
#  (807657, '2'),
#  (809912, '4'),
#  (810104, '2'),
#  (826923, '2'),
#  (832226, '2'),
#  (836433, '2'),
# ...

# %% [markdown]
# 针对该K值计算本次的准确率

# %%
# %%sql
# select sum(acc)/count(*) 准确率 from
#     (select test_data.编号, if(test_data.分类=knn_pre.预测分类, 1, 0) acc
#      from test_data join knn_pre
#      on test_data.编号 = knn_pre.测试编号) as tmp;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 1 rows affected.
# [(Decimal('0.9643'),)]

# %% [markdown]
# ### 任务四 讨论最佳K

# %% [markdown]
# 算法参数是k，从1~487更改K的值，观察准确率的变化

# %%
# %%sql
# #drop table if exists acc_K;
# create table acc_K(
#     K int primary key,
#     accuracy double
# );
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# insert into acc_K
# select 17, sum(acc)/count(*) as 准确率 from
#     (select test_data.编号, if(test_data.分类=knn_pre.预测分类, 1, 0) acc
#      from test_data join knn_pre
#      on test_data.编号 = knn_pre.测试编号) as tmp;
#
# select * from acc_K
# order by K;
# Out:
#  * mysql://stu2000013121:***@162.105.146.37:43306
# 1 rows affected.
# 27 rows affected.
# [(1, 0.964285714),
#  (2, 0.948979591),
#  (3, 0.969387755),
#  (4, 0.954081632),
#  (5, 0.964285714),
#  (6, 0.959183673),
#  (7, 0.964285714),
#  (8, 0.959183673),
#  (9, 0.969387755),
#  (10, 0.959183673),
#  (16, 0.964285714),
#  (17, 0.964285714),
#  (20, 0.964285714),
#  (30, 0.959183673),
#  (32, 0.959183673),
#  (40, 0.959183673),
#  (50, 0.954081632),
#  (64, 0.954081632),
#  (128, 0.943877551),
#  (150, 0.943877551),
#  (180, 0.933673469),
#  (200, 0.928571428),
#  (256, 0.897959183),
#  (300, 0.857142857),
#  (350, 0.632653061),
#  (400, 0.632653061),
#  (487, 0.632653061)]

# %% [markdown]
# 对上表分析发现，K取奇数的准确率普遍高于K取偶数时的准确率。
#
# &#8195; 分析原因：这与统计最近距离点时的数值筛选有关，偶数的K个点可能出现两种分类一样多的情况，在这种情况下，人为判给了分类2，由此可能导致误差，而奇数的K值则避免了这种情况。
#
# 当K值大于200时，准确率出现了明显的下降.
#
# **K值与准确率的变化趋势符合如下结论：**
#
# &#8195; K值越大，模型的偏差越大，对噪声数据越不敏感；
# &#8195; K值很大时，可能造成模型欠拟合；
# &#8195; K值越小，模型的方差就会越大；
# &#8195; K值太小，容易过拟合。

# %% [markdown]
# ### 与scikit-learn包获得的准确率作对比

# %% [markdown]
# 为不影响数据集的分组，使用相同的训练集和测试集进行对比

# %%
import pandas as pd
import pymysql
from sklearn.model_selection import train_test_split

#连接数据库，拉取数据表
connection = pymysql.connect(host='162.105.146.37',
                             port=43306,
                             user='stu2000013121',
                             password='stu2000013121',
                             database='stu2000013121')
cursor = connection.cursor()

#从训练集和测试集分别拉取数据转化为dataframe进行训练
cursor.execute("select * from train_data")
data1 = cursor.fetchall()
frame1 = pd.DataFrame(data1)
train_data = frame1

cursor.execute("select * from test_data")
data2 = cursor.fetchall()
frame2 = pd.DataFrame(data2)
test_data = frame2

column = ['编号','厚度','大小','形状','边缘','单核大小','裸核','染色质','核心','有丝分裂','分类','随机数']
train_data.columns = column
test_data.columns = column

# %% [markdown]
# 选择进行训练和要分类的属性

# %%
X_train = train_data.drop(['编号', '随机数', '分类'], axis=1)
y_train = train_data['分类']
X_test = test_data.drop(['编号', '随机数', '分类'], axis=1)
y_test = test_data['分类']

# %% [markdown]
# 对每个测试点都有487个距离，使K在1~487之间变动，记录准确率的变化
#
# 同时统计最高准确率的数值与对应的K值

# %%
from sklearn.neighbors import KNeighborsClassifier

maxx = 0
tmp = 0
for k in range(1, 487):
    knn = KNeighborsClassifier(n_neighbors=k, weights='uniform')
    knn.fit(X_train, y_train)
    print(f"k = {k}, accuracy = {knn.score(X_test, y_test)}")
    if knn.score(X_test, y_test) > maxx:
        tmp = k
    maxx = max(maxx, knn.score(X_test, y_test))
    
print("max accuracy = ", maxx)
print("best k = ", tmp)
# Out:
# k = 1, accuracy = 0.9642857142857143
# k = 2, accuracy = 0.9489795918367347
# k = 3, accuracy = 0.9693877551020408
# k = 4, accuracy = 0.9540816326530612
# k = 5, accuracy = 0.9642857142857143
# k = 6, accuracy = 0.9591836734693877
# k = 7, accuracy = 0.9642857142857143
# k = 8, accuracy = 0.9591836734693877
# k = 9, accuracy = 0.9693877551020408
# k = 10, accuracy = 0.9591836734693877
# k = 11, accuracy = 0.9591836734693877
# k = 12, accuracy = 0.9591836734693877
# k = 13, accuracy = 0.9642857142857143
# k = 14, accuracy = 0.9642857142857143
# k = 15, accuracy = 0.9642857142857143
# k = 16, accuracy = 0.9642857142857143
# k = 17, accuracy = 0.9693877551020408
# k = 18, accuracy = 0.9642857142857143
# k = 19, accuracy = 0.9642857142857143
# k = 20, accuracy = 0.9642857142857143
# k = 21, accuracy = 0.9642857142857143
# k = 22, accuracy = 0.9591836734693877
# k = 23, accuracy = 0.9591836734693877
# k = 24, accuracy = 0.9591836734693877
# k = 25, accuracy = 0.9642857142857143
# ...

# %% [markdown]
# 对比上述结果可知，
#
# &#8195;sklearn的最小的最佳K值为3，对应的最高准确率为0.9694
#
# &#8195;sql得到的最小的最佳K值为3，对应的最高准确率为0.9694，与sklearn结果一致，因此取得了较好的效果
